# %%
# !pip install torch torchvision diffusers transformers accelerate bitsandbytes scipy numpy Pillow opencv-python sentencepiece protobuf -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 20.0 MB/s eta 0:00:00

# %%
from huggingface_hub import login
hf_token="your HF token"
login(token=hf_token)

# %%
from huggingface_hub import HfApi
api = HfApi()

print(api.model_info("black-forest-labs/FLUX.1-dev"))
# Out:
# ModelInfo(id='black-forest-labs/FLUX.1-dev', author='black-forest-labs', sha='3de623fc3c33e44ffbe2bad470d0f45bccf2eb21', created_at=datetime.datetime(2024, 7, 31, 21, 13, 44, tzinfo=datetime.timezone.utc), last_modified=datetime.datetime(2025, 6, 27, 16, 22, 19, tzinfo=datetime.timezone.utc), private=False, disabled=False, downloads=673489, downloads_all_time=None, gated='auto', gguf=None, inference='warm', inference_provider_mapping=None, likes=12128, library_name='diffusers', tags=['diffusers', 'safetensors', 'text-to-image', 'image-generation', 'flux', 'en', 'license:other', 'endpoints_compatible', 'diffusers:FluxPipeline', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data={'base_model': None, 'datasets': None, 'eval_results': None, 'language': ['en'], 'library_name': None, 'license': 'other', 'license_name': 'flux-1-dev-non-commercial-license', 'license_link': 'LICENSE.md', 'metrics': None, 'model_name': None, 'pipeline_tag': None, 'tags': ['text-to-image', '
# ...

# %%
import os

os.environ['HF_TOKEN'] = hf_token
os.environ['PYTORCH_ALLOC_CONF'] = 'expandable_segments:True'

# !python txt2img.py \
    --prompt "A futuristic cyberpunk city with neon lights" \
    --models sdxl\
    --quantization fp4 fp8 fp16\
    --output_dir output/txt2img --mode txt2img\
    --seed 125
# Out:
# 2026-01-08 18:38:14.267424: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767897494.290192    1506 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767897494.296725    1506 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767897494.312754    1506 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python img2img.py \
    --input_dir path/to/input_images \
    --prompt "oil painting, van gogh style, thick brushstrokes" \
    --models sd15 sd3 sd35 \
    --quantization fp16 fp8 fp4 \
    --strength 0.6 \
    --output_dir output/img2img
# Out:
# 2025-12-12 16:38:31.765641: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765557511.785016     687 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765557511.791288     687 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765557511.807103     687 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python img2img.py \
    --input_dir demo_images/ \
    --prompt "oil painting, van gogh style, thick brushstrokes" \
    --models sd15 sd3 sd35 \
    --quantization fp16 fp8 fp4 \
    --strength 0.6 \
    --output_dir output/img2img
# Out:
# 2025-12-12 16:42:06.696907: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765557726.961116    1642 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765557727.030573    1642 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765557727.544277    1642 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import os

os.environ['HF_TOKEN'] = hf_token
os.environ['PYTORCH_ALLOC_CONF'] = 'expandable_segments:True'

# !python txt2img.py \
    --prompt "A futuristic cyberpunk city with neon lights" \
    --models sdxl\
    --quantization fp4 fp8 fp16\
    --output_dir output/txt2img --mode txt2img\
    --seed 125
# Out:
# 2026-01-08 12:02:34.783487: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767873755.029400   24926 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767873755.094255   24926 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767873755.358408   24926 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
